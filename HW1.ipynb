# %%
import pandas as pd
import numpy as np
import re
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
dataSet = pd.read_csv("spam_ham_dataset.csv") 
dataSet = dataSet.drop(['label'], axis='columns')
dataSet
# Out:
#       Unnamed: 0                                               text  label_num
# 0            605  Subject: enron methanol ; meter # : 988291\r\n...          0
# 1           2349  Subject: hpl nom for january 9 , 2001\r\n( see...          0
# 2           3624  Subject: neon retreat\r\nho ho ho , we ' re ar...          0
# 3           4685  Subject: photoshop , windows , office . cheap ...          1
# 4           2030  Subject: re : indian springs\r\nthis deal is t...          0
# ...          ...                                                ...        ...
# 5166        1518  Subject: put the 10 on the ft\r\nthe transport...          0
# 5167         404  Subject: 3 / 4 / 2000 and following noms\r\nhp...          0
# 5168        2933  Subject: calpine daily gas nomination\r\n>\r\n...          0
# 5169        1409  Subject: industrial worksheets for august 2000...          0
# 5170        4807  Subject: important online banking alert\r\ndea...          1
#
# [5171 rows x 3 columns]

# %%
#cleaning functions
class data_preprocessing:
    #function to seperate each word in the email
    def word_tokenization(self, text):
        words = re.findall(r'\w+', text)
        return words
    
    #makes each word lower case
    def lower_case(self, text):
        lowerCaseWords = text.lower()
        return lowerCaseWords
    
    #removes puncuation to make text clearer to understand in case of typos
    def remove_puncuation(self, text):
        wordsWithoutPunc = re.sub(r'[^\w\s]', '', text)
        return wordsWithoutPunc
    
    #removes urls from emails
    def remove_urls(self, text):
        wordsWithoutURL = re.sub(r'https?://[^\s\n\r]+', '', text)
        return wordsWithoutURL

# %%
class features_extraction:
    #how many times a word appears in the ham class
    def ham_frequency_dictionary(self, dataSetX, dataSetY):
        hamWordFrequency = {}

        #obtain all words in the ham class
        hamClass = dataSetX[dataSetY == 0]
                
        #iterate over ham class
        for wordKeys in hamClass:
            #iterate over existing words in the dictionary
            for word in wordKeys:
                if word in hamWordFrequency:
                    hamWordFrequency[word] += 1
                else:
                    hamWordFrequency[word] = 0
        return hamWordFrequency
    
    #how many times a word appears in the spam class    
    def spam_frequency_dictionary(self, dataSetX, dataSetY):
        spamWordFrequency = {}
        
        #obtain all words in the spam class
        spamClass = dataSetX[dataSetY == 1]

        #iterate over spam class
        for wordKeys in spamClass:
            #iterate over existing words in the dictionary
            for word in wordKeys:
                if word in spamWordFrequency:
                    spamWordFrequency[word] += 1
                else:
                    spamWordFrequency[word] = 0                            
        return spamWordFrequency

    #count frequency of ham and spam words per email
    def extract_features(self, bias, dataSetX, dataSetY):
        dictCheck = features_extraction()
        hamDictionary = dictCheck.ham_frequency_dictionary(dataSetX, dataSetY)
        spamDictionary = dictCheck.spam_frequency_dictionary(dataSetX, dataSetY)
        freqPerEmail = {}
        i = 0

        for emails in dataSetX:
            positiveFreq = 0
            negativeFreq = 0
            for word in emails:                                     #looping through each word per email
                if (word in (hamDictionary and spamDictionary)):    #calculating frequencies of each email
                    positiveFreq += hamDictionary['word']
                    negativeFreq += spamDictionary['word']
                elif (word in hamDictionary):
                    positiveFreq += hamDictionary['word']
                else:
                    negativeFreq += spamDictionary['word']
            values = [bias, positiveFreq, negativeFreq]
            freqPerEmail[i] = values
            i += 1
        return freqPerEmail

# %%
#preprocess dataset before extracting features
cleaningFunc = data_preprocessing()
dataSet['text'] = dataSet['text'].apply(cleaningFunc.lower_case)
dataSet['text'] = dataSet['text'].apply(cleaningFunc.remove_puncuation)
dataSet['text'] = dataSet['text'].apply(cleaningFunc.remove_urls)
dataSet['text'] = dataSet['text'].apply(cleaningFunc.word_tokenization)

# %%
#extracting features
extraction = features_extraction()
features = extraction.extract_features(1, dataSet['text'], dataSet['label_num'])
print(f"Features: {features}")

WordsFrequency = features_extraction()
print(f"Ham Words Frequencies: {WordsFrequency.ham_frequency_dictionary(dataSet['text'], dataSet['label_num'])}")
print(f"Spam Words Frequencies: {WordsFrequency.spam_frequency_dictionary(dataSet['text'], dataSet['label_num'])}")
# Out:
# Features: {0: [1, 1749, 1316], 1: [1, 528, 308], 2: [1, 15477, 12460], 3: [1, 1452, 1232], 4: [1, 2112, 1652], 5: [1, 2574, 1960], 6: [1, 10659, 8484], 7: [1, 4158, 3528], 8: [1, 2640, 1680], 9: [1, 528, 308], 10: [1, 34254, 29064], 11: [1, 1881, 1596], 12: [1, 825, 448], 13: [1, 1617, 1372], 14: [1, 1089, 756], 15: [1, 46926, 39816], 16: [1, 14388, 10164], 17: [1, 3333, 2352], 18: [1, 6006, 4284], 19: [1, 3333, 2660], 20: [1, 8877, 6944], 21: [1, 3729, 2828], 22: [1, 528, 308], 23: [1, 1155, 896], 24: [1, 40029, 33964], 25: [1, 8019, 5180], 26: [1, 11187, 8988], 27: [1, 1518, 1092], 28: [1, 6996, 5180], 29: [1, 7029, 4872], 30: [1, 9900, 7672], 31: [1, 825, 392], 32: [1, 5742, 4396], 33: [1, 8283, 6300], 34: [1, 5016, 3864], 35: [1, 19107, 16212], 36: [1, 1551, 812], 37: [1, 462, 392], 38: [1, 1848, 1148], 39: [1, 3861, 2688], 40: [1, 2640, 2240], 41: [1, 1122, 952], 42: [1, 2013, 1512], 43: [1, 825, 392], 44: [1, 4719, 3640], 45: [1, 7590, 5544], 46: [1, 8481, 7196], 47: [1, 5049, 4284], 48: [1, 3135, 2660], 49: [1, 42405, 28840], 50: [1, 9339, 7924], 51: [1, 264, 168], 52: [1, 1881, 1372], 53: [1, 34782, 28196], 54: [1, 11616, 8876], 55: [1, 1221, 924], 56: [1, 6666, 5264], 57: [1, 2277, 1316], 58: [1, 2211, 1400], 59: [1, 1023, 700], 60: [1, 42834, 36344], 61: [1, 5775, 4088], 62: [1, 6171, 4928], 63: [1, 2574, 1960], 64: [1, 13596, 10108], 65: [1, 528, 280], 66: [1, 1749, 1372], 67: [1, 3762, 2996], 68: [1, 3564, 3024], 69: [1, 1188, 924], 70: [1, 1914, 1624], 71: [1, 231, 196], 72: [1, 2013, 1400], 73: [1, 8679, 6860], 74: [1, 1122, 952], 75: [1, 2574, 2184], 76: [1, 12771, 9576], 77: [1, 7029, 5544], 78: [1, 3828, 3080], 79: [1, 4719, 3472], 80: [1, 8745, 6944], 81: [1, 1716, 1148], 82: [1, 3828, 2576], 83: [1, 528, 308], 84: [1, 2277, 1708], 85: [1, 12672, 10752], 86: [1, 3366, 2744], 87: [1, 528, 252], 88: [1, 1287, 756], 89: [1, 363, 224], 90: [1, 1320, 1120], 91: [1, 30822, 26152], 92: [1, 14553, 12348], 93: [1, 2607, 2212], 94: [1, 396, 336], 95: [1, 11187, 8988], 96: [1, 891, 728], 97: [1, 528, 308], 98: [1, 1980, 1680], 99: [1, 1353, 1036], 100: [1, 1848, 1456], 101: [1, 9933, 7056], 102: [1, 1221, 840], 103: [1, 3399, 2884], 104: [1, 264, 224], 105: [1, 1485, 1148], 106: [1, 2871, 2436], 107: [1, 1650, 1232], 108: [1, 1716, 1092], 109: [1, 1980, 1680], 110: [1, 2145, 1820], 111: [1, 6930, 5404], 112: [1, 9405, 7168], 113: [1, 3036, 2408], 114: [1, 858, 588], 115: [1, 2145, 1820], 116: [1, 13035, 9100], 117: [1, 363, 224], 118: [1, 3432, 2464], 119: [1, 1584, 1232], 120: [1, 528, 280], 121: [1, 1122, 700], 122: [1, 8052, 5796], 123: [1, 2244, 1372], 124: [1, 3168, 2688], 125: [1, 4059, 3108], 126: [1, 9636, 8176], 127: [1, 2739, 2156], 128: [1, 4026, 3416], 129: [1, 561, 476], 130: [1, 3168, 2436], 131: [1, 3036, 2464], 132: [1, 429, 308], 133: [1, 2310, 1428], 134: [1, 7062, 5992], 135: [1, 15873, 13468], 136: [1, 11814, 8568], 137: [1, 10824, 9184], 138: [1, 1452, 1232], 139: [1, 4785, 4060], 140: [1, 7755, 5656], 141: [1, 14916, 12656], 142: [1, 17853, 13468], 143: [1, 3333, 2492], 144: [1, 198, 168], 145: [1, 2673, 1652], 146: [1, 1815, 1064], 147: [1, 32703, 27748], 148: [1, 4686, 2800], 149: [1, 1650, 1036], 150: [1, 2409, 1652], 151: [1, 24090, 17444], 152: [1, 2871, 2072], 153: [1, 990, 728], 154: [1, 33, 28], 155: [1, 23034, 17556], 156: [1, 4818, 3808], 157: [1, 4125, 3500], 158: [1, 2475, 2100], 159: [1, 2673, 2156], 160: [1, 43626, 26936], 161: [1, 528, 308], 162: [1, 165, 140], 163: [1, 2442, 2072], 164: [1, 1584, 1344], 165: [1, 2508, 1792], 166: [1, 2112, 1428], 167: [1, 6303, 4396], 168: [1, 1254, 896], 169: [1, 6897, 5152], 170: [1, 9174, 7056], 171: [1, 6864, 5264], 172: [1, 1023, 756], 173: [1, 2013, 1596], 174: [1, 1089, 728], 175: [1, 5478, 4648], 176: [1, 33924, 28784], 177: [1, 825, 392], 178: [1, 1485, 896], 179: [1, 15213, 12908], 180: [1, 165, 140], 181: [1, 1881, 1344], 182: [1, 33, 28], 183: [1, 15312, 11900], 184: [1, 2607, 2212], 185: [1, 4059, 3052], 186: [1, 5511, 4676], 187: [1, 4 ...
# Ham Words Frequencies: {'subject': 6402, 'enron': 6554, 'methanol': 120, 'meter': 2458, '988291': 2, 'this': 4877, 'is': 4905, 'a': 6025, 'follow': 97, 'up': 990, 'to': 15171, 'the': 18358, 'note': 211, 'i': 5240, 'gave': 45, 'you': 5364, 'on': 6048, 'monday': 255, '4': 1082, '3': 1682, '00': 1818, 'preliminary': 52, 'flow': 672, 'data': 196, 'provided': 67, 'by': 2328, 'daren': 1900, 'please': 2714, 'override': 5, 'pop': 12, 's': 2110, 'daily': 554, 'volume': 876, 'presently': 11, 'zero': 161, 'reflect': 91, 'activity': 269, 'can': 1407, 'obtain': 12, 'from': 3209, 'gas': 2860, 'control': 160, 'change': 646, 'needed': 150, 'asap': 67, 'for': 7981, 'economics': 14, 'purposes': 26, 'hpl': 2317, 'nom': 830, 'january': 355, '9': 663, '2001': 2023, 'see': 1017, 'attached': 1082, 'file': 651, 'hplnol': 47, '09': 810, 'xls': 1019, 'neon': 74, 'retreat': 6, 'ho': 2, 'we': 3201, 're': 1752, 'around': 107, 'that': 3418, 'most': 102, 'wonderful': 8, 'time': 632, 'of': 5676, 'year': 237, 'leaders': 16, 'know': 1437, 'extremely': 8, 'hectic': 1, 'and': 7911, 'it': 2245, 'tough': 4, 'think': 317, 'about': 544, 'anything': 168, 'past': 65, 'holidays': 20, 'but': 776, 'life': 30, 'does': 207, 'go': 262, 'week': 308, 'december': 277, '25': 489, 'through': 340, '1': 2022, 'what': 757, 'd': 1657, 'like': 417, 'minute': 13, 'calender': 0, 'handed': 1, 'out': 815, 'at': 2990, 'beginning': 127, 'fall': 13, 'semester': 7, 'was': 1310, 'scheduled': 184, 'weekend': 102, '5': 1054, '6': 735, 'because': 182, 'youth': 2, 'ministers': 0, 'conference': 19, 'brad': 31, 'dustin': 6, 'are': 2219, 'connected': 14, 'with': 2515, 'going': 212, 'date': 289, 'following': 610, '12': 1205, '13': 391, 'now': 412, 'comes': 24, 'part': 124, 'need': 1256, 'all': 1043, 'agree': 144, 'important': 65, 'us': 546, 'get': 789, 'together': 95, 'have': 3208, 'some': 546, 'recharge': 0, 'our': 1054, 'batteries': 2, 'before': 201, 'far': 35, 'into': 759, 'spring': 57, 'be': 3756, 'lot': 40, 'trouble': 18, 'difficult': 13, 'away': 48, 'without': 91, 'kids': 31, 'etc': 71, 'so': 808, 'came': 40, 'potential': 52, 'alternative': 19, 'how': 317, 'then': 245, 'let': 1085, 'me': 2058, 'which': 550, 'prefer': 12, 'first': 362, 'option': 92, 'would': 874, 'similar': 35, 've': 149, 'done': 203, 'several': 104, 'years': 65, 'could': 389, 'heartland': 0, 'country': 28, 'inn': 0, 'www': 168, 'com': 2716, 'outside': 39, 'brenham': 2, 'nice': 15, 'place': 180, 'where': 207, 'bedroom': 1, 'house': 26, 'side': 62, 'in': 4569, 'real': 49, 'relaxing': 1, 'also': 551, 'close': 93, 'only': 442, 'one': 542, 'hour': 40, '15': 554, 'minutes': 14, 'here': 356, 'golf': 56, 'shop': 21, 'antique': 0, 'craft': 1, 'stores': 12, 'eat': 14, 'dinner': 19, 'ranch': 146, 'spend': 16, 'each': 322, 'other': 377, 'meet': 84, 'saturday': 93, 'return': 93, 'sunday': 69, 'morning': 131, 'just': 492, 'second': 59, 'stay': 65, 'houston': 448, 'restaurant': 1, 'dessert': 0, 'visiting': 10, 'recharging': 0, 'homes': 3, 'evening': 43, 'might': 106, 'easier': 22, 'trade': 119, 'off': 235, 'wouldn': 13, 't': 893, 'as': 1955, 'much': 131, 'll': 255, 'decide': 17, 'email': 357, 'back': 439, 'your': 2089, 'preference': 3, 'course': 38, 'if': 2585, 'available': 200, 'democratic': 2, 'process': 220, 'will': 3440, 'prevail': 1, 'majority': 5, 'vote': 6, 'rule': 19, 'hear': 60, 'soon': 157, 'possible': 164, 'preferably': 3, 'end': 217, 'doesn': 45, 'way': 154, 'no': 622, 'complaining': 1, 'allowed': 21, 'tend': 2, 'do': 955, 'great': 131, 'fishing': 3, 'shopping': 38, 'or': 1776, 'whatever': 24, 'makes': 21, 'happy': 37, 'bobby': 23, 'indian': 10, 'springs': 13, 'deal': 2788, 'book': 122, 'teco': 443, 'pvr': 24, 'revenue': 19, 'my': 586, 'understanding': 75, 'sends': 7, 'check': 198, 'haven': 37, 'received': 219, 'an': 902, 'answer': 70, 'whether': 54, 'there': 982, 'predermined': 0, 'price': 734, 'associated': 58, 'lets': 13, 'giving': 26, 'continue': 179, 'chase': 17, 'down': 238, 'ehronline': 25, 'web': 127, 'address': 165, 'mess ...
# Spam Words Frequencies: {'subject': 1656, 'photoshop': 79, 'windows': 206, 'office': 180, 'cheap': 78, 'main': 15, 'trending': 1, 'abasements': 0, 'darer': 0, 'prudently': 0, 'fortuitous': 1, 'undergone': 0, 'lighthearted': 0, 'charm': 0, 'orinoco': 0, 'taster': 0, 'railroad': 2, 'affluent': 1, 'pornographic': 0, 'cuvier': 0, 'irvin': 0, 'parkhouse': 0, 'blameworthy': 0, 'chlorophyll': 0, 'robed': 0, 'diagrammatic': 1, 'fogarty': 0, 'clears': 0, 'bayda': 1, 'inconveniencing': 0, 'managing': 6, 'represented': 0, 'smartness': 0, 'hashish': 1, 'academies': 0, 'shareholders': 17, 'unload': 0, 'badness': 0, 'danielson': 0, 'pure': 3, 'caffein': 0, 'spaniard': 2, 'chargeable': 1, 'levin': 0, 'looking': 253, 'for': 2522, 'medication': 33, 'we': 1136, 're': 230, 'the': 7253, 'best': 253, 'source': 70, 'it': 1087, 'is': 2255, 'difficult': 7, 'to': 5159, 'make': 192, 'our': 1034, 'material': 87, 'condition': 12, 'better': 87, 'by': 667, 'law': 19, 'but': 304, 'easy': 98, 'enough': 33, 'ruin': 2, 'bad': 36, 'laws': 11, 'excuse': 2, 'me': 508, 'you': 2793, 'just': 263, 'found': 48, 'and': 4902, 'simpliest': 2, 'site': 161, 'on': 1258, 'net': 220, 'no': 756, 'perscription': 3, 'delivery': 47, 'private': 85, 'secure': 63, 'see': 181, 'rightly': 0, 'a': 3786, 'pound': 3, 'week': 93, 'than': 193, 'squint': 0, 'million': 198, 've': 107, 'got': 66, 'anything': 23, 'that': 1347, 'will': 690, 'ever': 77, 'want': 211, 'erection': 22, 'treatment': 34, 'pills': 310, 'anti': 34, 'depressant': 10, 'weight': 86, 'loss': 68, 'more': 602, 'http': 982, 'splicings': 0, 'bombahakcx': 0, 'com': 991, '3': 1238, 'knowledge': 10, 'human': 12, 'power': 69, 'are': 1166, 'synonymous': 2, 'only': 505, 'high': 184, 'quality': 119, 'stuff': 18, 'low': 153, 'rates': 67, '100': 251, 'moneyback': 2, 'guarantee': 55, 'there': 252, 'god': 29, 'nature': 2, 'sufficeth': 0, 'unto': 0, 'herself': 5, 'in': 3128, 'wise': 5, 'hath': 2, 'she': 115, 'need': 222, 'of': 4489, 'an': 606, 'author': 9, 'vocable': 0, 'rnd': 55, 'word': 28, 'asceticism': 2, 'vcsc': 4, 'brand': 76, 'new': 431, 'stock': 298, 'your': 1945, 'attention': 39, 'vocalscape': 12, 'inc': 267, 'symbol': 40, 'be': 1302, 'top': 117, 'pick': 31, 'month': 97, 'april': 15, 'expected': 47, 'bounce': 6, '12': 138, 'cents': 20, 'level': 34, 'hit': 10, 'its': 344, 'all': 882, 'time': 360, 'back': 158, 'going': 77, 'explode': 32, 'next': 127, '5': 509, 'days': 123, 'watch': 91, 'soar': 11, 'go': 212, 'crazy': 7, 'this': 2282, 'breaking': 23, 'news': 223, 'announces': 27, 'agreement': 55, 'resell': 1, 'mix': 32, 'network': 58, 'services': 134, 'current': 87, 'price': 470, '0': 697, '025': 4, 'expect': 54, 'projected': 13, 'speculative': 56, '15': 226, 'networks': 22, 'building': 11, 'company': 727, 's': 1315, 'revolutionizing': 0, 'telecommunications': 14, 'industry': 99, 'with': 1469, 'most': 195, 'affordable': 33, 'phone': 129, 'systems': 51, 'hardware': 10, 'online': 256, 'software': 198, 'canada': 85, 'us': 467, 'global': 41, 'reach': 33, 'receiving': 29, 'international': 199, 'development': 86, 'voice': 46, 'over': 300, 'ip': 9, 'voip': 111, 'application': 48, 'solutions': 39, 'including': 99, 'award': 28, 'winning': 20, 'eyefontm': 0, 'softphone': 0, 'real': 102, 'pc': 55, 'advanced': 36, 'implementer': 0, 'pbx': 5, 'companies': 182, 'call': 74, 'centers': 8, 'itsps': 0, 'service': 161, 'providers': 20, 'has': 492, 'created': 12, 'interactive': 2, 'revolving': 1, 'around': 41, 'communications': 26, 'data': 59, 'convergence': 1, 'use': 210, 'internet': 194, 'protocol': 28, 'applications': 29, 'like': 242, 'pbxs': 0, 'softswitches': 0, '2': 857, 'web': 90, 'providing': 27, 'interaction': 1, 'information': 519, 'through': 175, 'businesses': 34, 'can': 612, 'offer': 163, 'anywhere': 24, 'world': 179, 'at': 742, 'significantly': 8, 'lower': 26, 'long': 124, 'distance': 9, 'charges': 6, 'develop': 15, 'run': 30, 'sell': 86, 'install': 6, 'own': 136, 'branded': 7, 'gateways': 2, 'gatekeeper': 0, 'control': 55, 'also': 209, 'li ...

# %%
#sigmoid function
def sigmoid(z):
            sigma = 1/(1+((np.e)**(-z)))
            return sigma

# %%
class logistic_regression:
    #includes parameter inilization, sigmoid func, calculate cost function, update parameters using gradient descent        
    def fit(self, bias, weight, weightTwo, iterationNumber, learningRate, trainDataSetX, trainDataSetY):
        
        m = len(trainDataSetX)
        parameters = [bias, weight, weightTwo]
        features = extraction.extract_features(bias, trainDataSetX, trainDataSetY)
        costFunction = 0
        gradient = 0

        for iteration in range(iterationNumber):
            sum = 0
            for email, labelNum in zip(features,trainDataSetY):                                             #iterating through each feature and labelNum in training set
                sigInput = np.dot(features[email], parameters) + costFunction
                sigResult = sigmoid(sigInput)                                                               #calculating sigmoid function
                gradient = ((1/m) * np.dot(features[email], (sigResult - labelNum)))
                parameters += (-learningRate*gradient)                                                      #updating parameters
                
                updatedSigInput = np.dot(features[email], parameters)
                updatedSigResult = sigmoid(updatedSigInput)
                sum += ((labelNum * np.log(updatedSigResult + 0.1)) + ((1 - labelNum) * np.log(1 - updatedSigResult + 0.1)))    #calculating summation in cost function
            costFunction = -(1/m) * sum

        return parameters[1], parameters[2]

    #testing the algorithim on the testing set
    def evaluate(self, weight, weightTwo, bias, testDataSetX, testDataSetY):
        total =  0
        tp = 0
        tn = 0
        fp = 0
        fn = 0
        parameters = [bias, weight, -weightTwo]
        features = extraction.extract_features(1, testDataSetX, testDataSetY)

        for email, labelNum in zip(features,testDataSetY):
            sum = 0
            sum = np.dot(features[email], parameters)

            output = sigmoid(sum) + 0.45
            
            #calculating TP,TN,FP,FN, the confusion matrix
            if(output > 0.5 and labelNum == 1):    #number of true positives
                total += 1
                tp += 1
            elif(output < 0.5 and labelNum == 0):  #number of true negatives
                total += 1
                tn += 1
            elif(output > 0.5 and labelNum == 0):  #number of false positives
                fp += 1 
            elif(output < 0.5 and labelNum == 1):  #number of false negatives
                fn += 1

        accuracy = (tp+tn)/(tp+fp+tn+fn)
        precision = tp/(tp+fp)
        recall = tp/(tp+fn)
        f1_score =  2*((precision*recall)/(precision+recall))

        return accuracy,precision,recall,f1_score

# %%
#splitting data
def split_data(dataset, testSize):
    splitData = int(len(dataset)*testSize)

    trainingSet = dataset[splitData:]
    testSet = dataSet[:splitData]
    
    x_train = trainingSet['text']
    y_train = trainingSet['label_num']
    x_test = testSet['text']
    y_test = testSet['label_num']
    
    return x_train, x_test, y_train, y_test

x_train, x_test, y_train, y_test = split_data(dataSet, 0.2)

# %%
#this takes a little over a minute to run
w = np.random.random()
wTwo = np.random.random()
bias = 1
iterationNumber = 1000
learningRate = 0.0001
regression = logistic_regression()

weightOne, weightTwo = regression.fit(bias, w, wTwo, iterationNumber, learningRate, x_train.to_numpy(), y_train.to_numpy())
accuracy, precision, recall, f1_score = regression.evaluate(weightOne, weightTwo, bias, x_test.to_numpy(), y_test.to_numpy())
# Out:
# /var/folders/43/8npkycb55rsc3hdztn2s3w2w0000gn/T/ipykernel_47165/1180926108.py:3: RuntimeWarning: overflow encountered in double_scalars
#   sigma = 1/(1+((np.e)**(-z)))

# %%
#confusion matrix
print(f"Accuracy = {accuracy}")
print(f"Precision = {precision}")
print(f"Recall = {recall}")
print(f"f1_score = {f1_score}")
# Out:
# Accuracy = 0.7166344294003868
# Precision = 0.8235294117647058
# Recall = 0.046052631578947366
# f1_score = 0.08722741433021806

# %%
#sklearn module
#ReRun only cells 1,2, and 9 before running this one
vec = TfidfVectorizer(max_features=1000)  # You can adjust max_features as needed
x = vec.fit_transform(dataSet['text'])

x_train, x_test, y_train, y_test = train_test_split(x, dataSet['label_num'], test_size=0.2, random_state=42)

reg = LogisticRegression()
reg.fit(x_train, y_train)
reg.score(x_test, y_test)
# Out:
# 0.9748792270531401
